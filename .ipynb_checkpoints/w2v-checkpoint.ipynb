# %%
import pandas as pd

# %%
data = pd.read_csv('data/data_w_genres.csv')
corpus = data['genres']
corpus = corpus[corpus != '[]']
corpus = corpus.str.lstrip('[')
corpus = corpus.str.rstrip(']')
corpus = corpus.str.replace("'", '')
corpus.head()
# Out:
# 0                                            show tunes
# 8                            comedy rock, comic, parody
# 9     emo rap, florida rap, sad rap, underground hip...
# 10                                  dark trap, meme rap
# 12    asian american hip hop, cali rap, west coast trap
# Name: genres, dtype: object

# %%
genres = []
for values in corpus:
    for genre in values.split(', '):
        genres.append(genre)
genres = set(genres)

# %%
len(genres)
# Out:
# 2972

# %%
len(corpus)
# Out:
# 18823

# %% [markdown]
# mapping from tokens (genres) to integer indices and vice versa

# %%
genre2int = {}

for i,genre in enumerate(genres):
    genre2int[genre] = i

genre2int
# Out:
# {'vancouver metal': 0,
#  'hip hop cubano': 1,
#  'italian gothic': 2,
#  'arabesk': 3,
#  'psychedelic doom': 4,
#  'washboard': 5,
#  'tollywood': 6,
#  'finnish heavy metal': 7,
#  'auckland indie': 8,
#  'australian ambient': 9,
#  'finnish edm': 10,
#  'indian instrumental': 11,
#  'classical trumpet': 12,
#  'canzone napoletana': 13,
#  'kashmiri pop': 14,
#  'tabla': 15,
#  'world worship': 16,
#  'corridos tumbados': 17,
#  'american contemporary classical': 18,
#  'boston hardcore': 19,
#  'modern folk rock': 20,
#  'bansuri': 21,
#  'opera metal': 22,
#  'nova mpb': 23,
#  'opera chorus': 24,
#  'bandoneon': 25,
#  'reggaeton': 26,
#  'jazz blues': 27,
#  'chaotic hardcore': 28,
#  'caucasian classical piano': 29,
#  'hard minimal techno': 30,
#  'israeli hip hop': 31,
#  'italian jazz': 32,
#  'nyc rap': 33,
#  'hardcore techno': 34,
#  'mandolin': 35,
#  'kingston on indie': 36,
#  'classic greek pop': 37,
#  'new york drill': 38,
#  'banda': 39,
#  'corrido': 40,
#  'english indie rock': 41,
#  'pinoy hip hop': 42,
#  'dutch rock': 43,
#  'russian pop': 44,
#  'new jersey rap': 45,
#  'spanish hip hop': 46,
#  'filmi': 47,
#  'finnish metal': 48,
#  'uplifting trance': 49,
#  'meme rap': 50,
#  'jazz metal': 51,
#  'nantes indie': 52,
#  'instrumental acoustic guitar': 53,
#  'post-minimalism': 54,
#  'deep euro house': 55,
#  'christmas product': 56,
#  'ska chileno': 57,
#  'musica paraibana': 58,
#  'historic string quartet': 59,
#  'surf music': 60,
#  'broadway': 61,
#  'syrian pop': 62,
#  'devon indie': 63,
#  'grave wave': 64,
#  'd-beat': 65,
#  'classic soul': 66,
#  'instrumental bluegrass': 67,
#  'dc indie': 68,
#  'portuguese early music': 69,
#  'deathcore': 70,
#  'j-pop girl group': 71,
#  'jamgrass': 72,
#  'japanese rockabilly': 73,
#  'german power metal': 74,
#  'guinean pop': 75,
#  'reggae rock': 76,
#  'brazilian contemporary classical': 77,
#  'lo-fi': 78,
#  'austrian classical piano': 79,
#  'classical piano': 80,
#  'belarusian pop': 81,
#  'dark jazz': 82,
#  'psychedelic folk rock': 83,
#  'son cubano clasico': 84,
#  'delta blues': 85,
#  'chakra': 86,
#  'finnish hard rock': 87,
#  'rosary': 88,
#  'japanese concert band': 89,
#  'c-pop': 90,
#  'pop rap': 91,
#  'argentine telepop': 92,
#  'rare groove': 93,
#  'zurich indie': 94,
#  'ok indie': 95,
#  'livetronica': 96,
#  'neo-traditional bluegrass': 97,
#  'musikkorps': 98,
#  'oc indie': 99,
#  'danish punk': 100,
#  'hungarian classical performance': 101,
#  'folk rock': 102,
#  'hungarian folk': 103,
#  'canadian rock': 104,
#  'viral pop': 105,
#  'vienna indie': 106,
#  'japanese electronic': 107,
#  'nwothm': 108,
#  'instrumental math rock': 109,
#  'greek contemporary classical': 110,
#  'organic electronic': 111,
#  '"preschool childrens music"': 112,
#  'narodna muzika': 113,
#  'czech classical': 114,
#  'j-acoustic': 115,
#  'japanese heavy metal': 116,
#  'german trance': 117,
#  'progressive psytrance': 118,
#  'madrigal': 119,
#  'uk house': 120,
#  'comic': 121,
#  'chanson': 122,
#  'tunisian pop': 123,
#  'japanese electropop': 124,
#  'musica llanera': 125,
#  'classic uk pop': 126,
#  'braindance': 127,
#  'desi hip hop': 128,
#  'sound art': 129,
#  'turkish experimental': 130,
#  'swedish heavy metal': 131,
#  'berlin minimal techno': 132,
#  'soft rock': 133,
#  'classical piano duo': 134,
#  'baltimore indie': 135,
#  'maine indie': 136,
#  'scottish electronic': 137,
#  'indie electronica': 138,
#  'velha guarda': 139,
#  'spanish invasion': 140,
#  'dutch prog': 141,
#  'mexican rock-and-roll': 142,
#  'atmospheric post-metal': 143,
#  'cameroonian pop': 144,
#  'industrial rock': 145,
#  'abstract': 146,
#  'eugene indie': 147,
#  'spanish modern rock': 148,
#  'folk metal': 149,
#  'deep melodic metalcore': 150,
#  '"british childrens music"': 151,
#  'spanish rock': 152,
#  'german orchestra': 153,
#  'harmonica jazz': 154,
#  'uk alternative pop': 155,
#  'smooth saxophone': 156,
#  'rock steady': 157,
#  'british folk': 158,
#  'japanese soundtrack': 159,
#  'romanian classical piano': 160,
#  'kentucky hip hop': 161,
#  'dutch indie': 162,
#  'gothic alternative': 163,
#  'samba': 164,
#  'rap nacional antigo': 165,
#  'musica antigua': 166,
#  'italian blues': 167,
#  'post-grunge': 168,
#  'hi-nrg': 169,
#  'australian talent show': 170,
#  'sound team': 171,
#  'belgian singer-songwriter': 172,
#  'chilean hardcore': 173,
#  'post-doom metal': 174,
#  'indietronica': 175,
#  'chutney': 176,
#  'canadian blues': 177,
#  'rock drums': 178,
#  'gothic metal': 179,
#  'american 21st century classical': 180,
#  'indie poptimism': 181,
#  'pop quebecois': 182,
#  'mpb': 183,
#  'athens indie': 184,
#  'canadian indie': 185,
#  'german opera': 186,
#  'portland indie': 187,
#  'danish metal': 188,
#  'oakland indie': 189,
#  'mod revival': 190,
#  'uk hip hop': 191,
#  'dinner jazz': 192,
#  'folklore peruano': 193,
#  'italian renaissance': 194,
#  'punjabi hip hop': 195,
#  'jazz trumpet': 196,
#  'irish dance': 197,
#  'afroswing': 198,
#  'underground power pop': 199,
#  'swancore': 200,
#  'iowa hip hop': 201,
#  'oceania soundtrack': 202,
#  'sound': 203,
#  'lullaby': 204,
#  'zydeco': 205,
#  'hindi indie': 206,
#  'chillhop': 207,
#  'visor': 208,
#  'balkan brass': 209,
#  'kodomo no ongaku': 210,
#  'contemporary vocal jazz': 211,
#  'histoire pour enfants': 212,
#  'deep smooth jazz': 213,
#  'canadian comedy': 214,
#  'yacht rock': 215,
#  'stomp and holler': 216,
#  'indian classical': 217,
#  'anthem emo': 218,
#  'new england americana': 219,
#  'kizomba antigas': 220,
#  'afrofuturism': 221,
#  'piano mpb': 222,
#  'rochester ny indie': 223,
#  'rock urbano mexicano': 224,
#  'nueva ola peruana': 225,
#  'psicodelia brasileira': 226,
#  'afrobeat': 227,
#  'emo rap': 228,
#  'swedish prog': 229,
#  'reggae': 230,
#  'swedish singer-songwriter': 231,
#  'orchestra': 232,
#  'psybass': 233,
#  'frenchcore': 234,
#  'pop folk': 235,
#  'brostep': 236,
#  'yorkshire folk': 237,
#  'albuquerque indie': 238,
#  'middle east hip hop': 239,
#  'vocal ensemble': 240,
#  'rhode island rap': 241,
#  'italian classical guitar': 242,
#  'acoustic blues': 243,
#  'deep g funk': 244,
#  'colombian pop': 245,
#  'gospel': 246,
#  'mississippi indie': 247,
#  'german renaissance': 248,
#  'estonian pop': 249,
#  'quiet storm': 250,
#  '"canzone dautore"': 251,
#  'latin metal': 252,
#  'canadian indigenous hip hop': 253,
#  'baroque ensemble': 254,
#  'family gospel': 255,
#  'samba-enredo': 256,
#  'pop peruano': 257,
#  'portland metal': 258,
#  'nightrun': 259,
#  'chill pop': 260,
#  'minimal wave': 261,
#  'miami metal': 262,
#  'german jazz': 263,
#  'bay area indie': 264,
#  'indian edm': 265,
#  'pop violin': 266,
#  'irish country': 267,
#  'grupera': 268,
#  'swedish alternative rock': 269,
#  'russian ccm': 270,
#  'world meditation': 271,
#  'electro swing': 272,
#  'cypriot pop': 273,
#  'japanese chillhop': 274,
#  'italian mezzo-soprano': 275,
#  'cambridgeshire indie': 276,
#  'nintendocore': 277,
#  'streichquartett': 278,
#  'kentucky mountain folk': 279,
#  'swedish garage rock': 280,
#  'one-person band': 281,
#  'theremin': 282,
#  'classic czech pop': 283,
#  'britpop': 284,
#  'bible': 285,
#  'shabad': 286,
#  'brazilian edm': 287,
#  'sufi chant': 288,
#  'japanese instrumental': 289,
#  'bard': 290,
#  'san antonio rap': 291,
#  'glam punk': 292,
#  'american modern classical': 293,
#  'indie cafe pop': 294,
#  'diva house': 295,
#  'african reggae': 296,
#  'martial industrial': 297,
#  'atlanta indie': 298,
#  'south carolina indie': 299,
#  'cumbia peruana': 300,
#  'g funk': 301,
#  'philly soul': 302,
#  'impressionism': 303,
#  'dansband': 304,
#  'binaural': 305,
#  'classical bass': 306,
#  'christian hip hop': 307,
#  'pinoy indie': 308,
#  'traditional folk': 309,
#  'chamber folk': 310,
#  'danish pop rock': 311,
#  'soul jazz': 312,
#  'russian folk rock': 313,
#  'shanty': 314,
#  'swedish americana': 315,
#  'pakistani folk': 316,
#  'turkish trap': 317,
#  'depressive black metal': 318,
#  'trap chileno': 319,
#  'tennessee hip hop': 320,
#  'omaha indie': 321,
#  'rap conscient': 322,
#  'cello': 323,
#  'pagode baiano': 324,
#  'polyphony': 325,
#  'parody': 326,
#  'spanish baroque': 327,
#  'j-pixie': 328,
#  'ethereal wave': 329,
#  'guitarra argentina': 330,
#  'uk post-hardcore': 331,
#  'sudanese pop': 332,
#  'rock baiano': 333,
#  'austindie': 334,
#  'st louis rap': 335,
#  'pub rock': 336,
#  'classic israeli pop': 337,
#  'rock nacional brasileiro': 338,
#  'north east england indie': 339,
#  'musica popular paraense': 340,
#  'japanese pop punk': 341,
#  'french opera': 342,
#  'deep soft rock': 343,
#  'japanese classical': 344,
#  'japanese r&b': 345,
#  'west end': 346,
#  'neoclassical darkwave': 347,
#  'musica andina': 348,
#  'muzica populara': 349,
#  'vocal trance': 350,
#  'chamber pop': 351,
#  'middle earth': 352,
#  'dallas indie': 353,
#  'japanese city pop': 354,
#  'early american folk': 355,
#  'deep disco': 356,
#  'uk post-punk': 357,
#  'teen pop': 358,
#  'swedish pop': 359,
#  'electro house': 360,
#  'acoustic punk': 361,
#  'classic russian pop': 362,
#  'piano rock': 363,
#  'swedish electronic': 364,
#  'scream rap': 365,
#  'australian alternative rock': 366,
#  'kawaii metal': 367,
#  'late romantic era': 368,
#  'boom bap': 369,
#  'relaxative': 370,
#  'dark techno': 371,
#  'west coast reggae': 372,
#  'disco house': 373,
#  'swedish synth': 374,
#  'french soundtrack': 375,
#  'musica para criancas': 376,
#  'mellow gold': 377,
#  'melodic rap': 378,
#  'progressive alternative': 379,
#  'tango cancion': 380,
#  'hard alternative': 381,
#  'classic j-rock': 382,
#  'indie quebecois': 383,
#  'oakland hip hop': 384,
#  'alaska indie': 385,
#  'turkish trap pop': 386,
#  'icelandic pop': 387,
#  'turkish edm': 388,
#  'native american contemporary': 389,
#  'partyschlager': 390,
#  'hungarian contemporary classical': 391,
#  'jazz tuba': 392,
#  'baglama': 393,
#  'mathcore': 394,
#  'nepali pop': 395,
#  'esperanto': 396,
#  'deep free jazz': 397,
#  'salsa international': 398,
#  'bachata': 399,
#  'classical countertenor': 400,
#  'psychill': 401,
#  'funk rock': 402,
#  'ska': 403,
#  'gaming edm': 404,
#  'swedish metal': 405,
#  'nz indie': 406,
#  'deep new americana': 407,
#  'greek pop': 408,
#  'freakbeat': 409,
#  'chamber ensemble': 410,
#  'chinese classical performance': 411,
#  'drill and bass': 412,
#  'canadian classical': 413,
#  'boogie': 414,
#  'christian a cappella': 415,
#  'florida rap': 416,
#  'bush ballad': 417,
#  'folk punk': 418,
#  'melbourne indie': 419,
#  'ambient idm': 420,
#  'latino comedy': 421,
#  'viola': 422,
#  'hong kong indie': 423,
#  'oshare kei': 424,
#  'asbury park indie': 425,
#  'ilocano pop': 426,
#  'icelandic experimental': 427,
#  'dangdut': 428,
#  'cumbia colombiana regia': 429,
#  'dark disco': 430,
#  'early music ensemble': 431,
#  'synthpop': 432,
#  'yugoslav new wave': 433,
#  'bay area hip hop': 434,
#  'honky tonk': 435,
#  'kentucky punk': 436,
#  'electro jazz': 437,
#  'york indie': 438,
#  'rabindra sangeet': 439,
#  'speed metal': 440,
#  'gypsy jazz': 441,
#  'dirty texas rap': 442,
#  'taiwan campus folk': 443,
#  'modern rock': 444,
#  'deep minimal techno': 445,
#  'german punk': 446,
#  'classical harp': 447,
#  'channel islands indie': 448,
#  'post-post-hardcore': 449,
#  'sevdah': 450,
#  'german soundtrack': 451,
#  'dutch edm': 452,
#  'la pop': 453,
#  'islamic recitation': 454,
#  'turkish jazz': 455,
#  'progressive trance': 456,
#  'gainesville indie': 457,
#  'idaho indie': 458,
#  'australian indie rock': 459,
#  'romanian electronic': 460,
#  'filthstep': 461,
#  'burmese traditional': 462,
#  'jewish hip hop': 463,
#  'indie rock': 464,
#  'deep soundtrack': 465,
#  'future funk': 466,
#  'guatemalan pop': 467,
#  'sovietwave': 468,
#  'turntablism': 469,
#  'rap dominicano': 470,
#  'nz punk': 471,
#  'vancouver indie': 472,
#  'musique peule': 473,
#  'belgian new wave': 474,
#  'ranchera': 475,
#  'rock kapak': 476,
#  'icelandic jazz': 477,
#  'electronic djent': 478,
#  'italian baroque ensemble': 479,
#  'turkish classical': 480,
#  'hindustani instrumental': 481,
#  'sheffield indie': 482,
#  'traditional country': 483,
#  'classic psychedelic rock': 484,
#  'lilith': 485,
#  'hauntology': 486,
#  'japanese post-hardcore': 487,
#  'grime': 488,
#  'sotalaulut': 489,
#  'christian rock': 490,
#  'texas country': 491,
#  'duduk': 492,
#  'classic garage rock': 493,
#  'israeli mediterranean': 494,
#  'mambo': 495,
#  'australian psych': 496,
#  'nouvelle chanson francaise': 497,
#  'merseybeat': 498,
#  'cymraeg': 499,
#  'dub poetry': 500,
#  'shakuhachi': 501,
#  'beach music': 502,
#  'hurdy-gurdy': 503,
#  'bhajan': 504,
#  'louisiana blues': 505,
#  'rune folk': 506,
#  'neofolk': 507,
#  'corrosion': 508,
#  'belarusian indie': 509,
#  'retro soul': 510,
#  'indian jazz': 511,
#  'afro house': 512,
#  'swedish jazz orkester': 513,
#  'soda pop': 514,
#  'swedish melodic rock': 515,
#  'georgian folk': 516,
#  'flick hop': 517,
#  'american orchestra': 518,
#  'belgian techno': 519,
#  'cinematic post-rock': 520,
#  'argentine ambient': 521,
#  'classic afrobeat': 522,
#  'nu age': 523,
#  'italian power metal': 524,
#  'nashville sound': 525,
#  'pop romantico': 526,
#  'tex-mex': 527,
#  'minimal melodic techno': 528,
#  'italian library music': 529,
#  'new orleans jazz': 530,
#  'classic danish pop': 531,
#  'pittsburgh rap': 532,
#  '"childrens music"': 533,
#  'rock chapin': 534,
#  'australian post-punk': 535,
#  'canadian folk': 536,
#  'western swing': 537,
#  'italian indie pop': 538,
#  'experimental jazz': 539,
#  'pakistani pop': 540,
#  'nigerian hip hop': 541,
#  'exotica': 542,
#  'new americana': 543,
#  'anarcho-punk': 544,
#  'birmingham metal': 545,
#  'eastern bloc groove': 546,
#  'roots rock': 547,
#  'deep techno': 548,
#  'swedish jazz': 549,
#  'atlanta punk': 550,
#  'puerto rican folk': 551,
#  'belgian edm': 552,
#  'taiwan indie': 553,
#  'triangle indie': 554,
#  'plunderphonics': 555,
#  'korean classical performance': 556,
#  'marching band': 557,
#  'afro dancehall': 558,
#  'cumbia ranchera': 559,
#  'breakcore': 560,
#  'celtic punk': 561,
#  'dixieland': 562,
#  'rap': 563,
#  'jazz double bass': 564,
#  'minneapolis indie': 565,
#  'okinawan pop': 566,
#  'background music': 567,
#  'sky room': 568,
#  'panamanian rock': 569,
#  'rock alternativo brasileiro': 570,
#  'swedish choir': 571,
#  'dungeon synth': 572,
#  'polish post-rock': 573,
#  'dance-punk': 574,
#  'hands up': 575,
#  'indonesian r&b': 576,
#  'spanish pop': 577,
#  'appalachian folk': 578,
#  'australian metal': 579,
#  'country dawn': 580,
#  'vermont indie': 581,
#  'vancouver punk': 582,
#  'contemporary classical': 583,
#  'australian electropop': 584,
#  'polish classical piano': 585,
#  'kiwi rock': 586,
#  'gospel antigas': 587,
#  'tamaulipas indie': 588,
#  'christian music': 589,
#  'rhode island indie': 590,
#  'spanish techno': 591,
#  'light music': 592,
#  'hawaiian indie': 593,
#  'caucasian classical': 594,
#  'drift': 595,
#  'san diego indie': 596,
#  'lute': 597,
#  'jazz funk': 598,
#  'memphis indie': 599,
#  'halloween': 600,
#  'latin classical': 601,
#  'baroque violin': 602,
#  'lo-fi house': 603,
#  'sad rap': 604,
#  'deep ragga': 605,
#  'old school rap francais': 606,
#  'polka': 607,
#  'meditation': 608,
#  'ethio-jazz': 609,
#  'dubsteppe': 610,
#  'musica de fondo': 611,
#  'calming instrumental': 612,
#  'french dnb': 613,
#  'indie deutschrap': 614,
#  'musica gaucha tradicionalista': 615,
#  'shaabi': 616,
#  'pony': 617,
#  'columbus ohio indie': 618,
#  'j-punk': 619,
#  'danish pop': 620,
#  'beatlesque': 621,
#  'bassline': 622,
#  'arab pop': 623,
#  'brega': 624,
#  'melancholia': 625,
#  'turkish pop': 626,
#  'austrian orchestra': 627,
#  'jazz cubano': 628,
#  'salsa': 629,
#  'j-metal': 630,
#  'bossa nova jazz': 631,
#  'new age': 632,
#  'spanish metal': 633,
#  'boston folk': 634,
#  'minimal tech house': 635,
#  'gothic rock': 636,
#  'instrumental grime': 637,
#  'latin talent show': 638,
#  'deep freestyle': 639,
#  'indonesian pop': 640,
#  'toronto rap': 641,
#  'italian contemporary jazz': 642,
#  'ambient black metal': 643,
#  'vintage schlager': 644,
#  'fo jing': 645,
#  'garage rock': 646,
#  'dembow': 647,
#  'french post-punk': 648,
#  'celtic rock': 649,
#  'nashville indie': 650,
#  'modern alternative rock': 651,
#  'british grindcore': 652,
#  'nueva ola chilena': 653,
#  'musica piemonteisa': 654,
#  'boston metal': 655,
#  'chinese soundtrack': 656,
#  'north carolina emo': 657,
#  'uk doom metal': 658,
#  'supergroup': 659,
#  'australian country': 660,
#  'swedish stoner rock': 661,
#  'gymcore': 662,
#  'psychedelic trance': 663,
#  'south carolina metal': 664,
#  'classical baritone': 665,
#  'modern old-time': 666,
#  'modern alternative pop': 667,
#  'ritmo kombina': 668,
#  'chinese jazz': 669,
#  'vgm instrumental': 670,
#  'folk-pop': 671,
#  'oud': 672,
#  'polca paraguaya': 673,
#  'kannada bhava geethe': 674,
#  'perth indie': 675,
#  'disney': 676,
#  'new weird america': 677,
#  'polynesian pop': 678,
#  'political hip hop': 679,
#  'carnatic vocal': 680,
#  'psychedelic soul': 681,
#  'show tunes': 682,
#  'christian punk': 683,
#  'neo-classical': 684,
#  'argentine indie': 685,
#  'estonian hip hop': 686,
#  'croatian folk': 687,
#  'rap kreyol': 688,
#  'chillwave': 689,
#  'circus': 690,
#  'contemporary jazz': 691,
#  'merengue tipico': 692,
#  'straight-ahead jazz': 693,
#  'ny roots': 694,
#  '"muzika lyeladim"': 695,
#  'hungarian pop': 696,
#  'industrial hardcore': 697,
#  'miami bass': 698,
#  'progressive jazz fusion': 699,
#  'ottawa rap': 700,
#  'pop venezolano': 701,
#  'italian opera': 702,
#  'pop punk': 703,
#  'pixie': 704,
#  'traditional blues': 705,
#  'carnatic': 706,
#  'transpop': 707,
#  'neue deutsche todeskunst': 708,
#  'nueva cancion': 709,
#  'british modern classical': 710,
#  'cumbia sonidera': 711,
#  'samba de roda': 712,
#  'modern ska punk': 713,
#  'hawaiian': 714,
#  'classic indo pop': 715,
#  'dutch dnb': 716,
#  'string band': 717,
#  'german romanticism': 718,
#  'american folk revival': 719,
#  'seattle indie': 720,
#  'nederlandse hardstyle': 721,
#  'philly rap': 722,
#  'worship': 723,
#  'garage pop': 724,
#  'instrumental rock': 725,
#  'greek folk': 726,
#  'gothabilly': 727,
#  'jazztronica': 728,
#  'canadian experimental': 729,
#  'musica cristiana guatemalteca': 730,
#  'anglican liturgy': 731,
#  'boston rock': 732,
#  'italian progressive metal': 733,
#  'southern soul blues': 734,
#  'talent show': 735,
#  'scratch': 736,
#  'tribal house': 737,
#  'country rock': 738,
#  'jump up': 739,
#  'australian trap': 740,
#  'new england emo': 741,
#  'early avant garde': 742,
#  'birmingham hip hop': 743,
#  'latin afrobeat': 744,
#  'street punk': 745,
#  'emo punk': 746,
#  'polish contemporary classical': 747,
#  'scottish new wave': 748,
#  'canadian electropop': 749,
#  'viking black metal': 750,
#  'turkish modern jazz': 751,
#  'dub techno': 752,
#  'ambient techno': 753,
#  'birmingham grime': 754,
#  'uptempo hardcore': 755,
#  'reggae en espanol': 756,
#  'avant-garde': 757,
#  'norwegian death metal': 758,
#  'indie shoegaze': 759,
#  'vintage chinese pop': 760,
#  'brass quintet': 761,
#  'celtic metal': 762,
#  'atmospheric sludge': 763,
#  'thall': 764,
#  'groove room': 765,
#  'deep indie singer-songwriter': 766,
#  'funk paulista': 767,
#  'bristol indie': 768,
#  'danish jazz': 769,
#  'dream pop': 770,
#  'substep': 771,
#  'dabke': 772,
#  'swedish doom metal': 773,
#  'bhangra': 774,
#  'washington indie': 775,
#  'old-time fiddle': 776,
#  'jangle pop': 777,
#  'historically informed performance': 778,
#  'french movie tunes': 779,
#  'hard rock': 780,
#  'opera': 781,
#  'japanese psychedelic': 782,
#  'swedish tropical house': 783,
#  'thai pop': 784,
#  'old school thrash': 785,
#  'bubblegrunge': 786,
#  'philly indie': 787,
#  'german baroque': 788,
#  'us power metal': 789,
#  'uk diy punk': 790,
#  'rhythm and blues': 791,
#  'baroque woodwind': 792,
#  'british invasion': 793,
#  'chill guitar': 794,
#  'dutch death metal': 795,
#  'east coast hip hop': 796,
#  'nu disco': 797,
#  'ethnotronica': 798,
#  'indie rockism': 799,
#  'german underground rap': 800,
#  'german hard rock': 801,
#  'dutch trance': 802,
#  'shred': 803,
#  'classical mandolin': 804,
#  'latin ska': 805,
#  'canadian post-hardcore': 806,
#  'timba': 807,
#  'avant-garde metal': 808,
#  'gospel singers': 809,
#  'tagalog rap': 810,
#  'rennes indie': 811,
#  'milwaukee indie': 812,
#  'knoxville indie': 813,
#  'k-indie': 814,
#  'spirituals': 815,
#  'neo-rockabilly': 816,
#  'jamtronica': 817,
#  'arizona punk': 818,
#  'movie tunes': 819,
#  'classic canadian rock': 820,
#  'norwegian singer-songwriter': 821,
#  'canadian hardcore': 822,
#  'pop r&b': 823,
#  'riot grrrl': 824,
#  'japanese vocal jazz': 825,
#  'minneapolis sound': 826,
#  'erhu': 827,
#  'modular synth': 828,
#  '"death n roll"': 829,
#  'experimental guitar': 830,
#  'fluxwork': 831,
#  'michigan indie': 832,
#  'baroque singing': 833,
#  'northern irish indie': 834,
#  'future rock': 835,
#  'j-pop': 836,
#  'german classical piano': 837,
#  'american primitive': 838,
#  'australian choir': 839,
#  'deep flow': 840,
#  'witch house': 841,
#  'gothic black metal': 842,
#  'tagalog worship': 843,
#  'lldm': 844,
#  'metropopolis': 845,
#  'romanian pop': 846,
#  'swedish power metal': 847,
#  'greek swing': 848,
#  'folk rock italiano': 849,
#  'jazz guitar': 850,
#  'art punk': 851,
#  'japanese folk': 852,
#  'tulsa indie': 853,
#  'panpipe': 854,
#  'venezuelan indie': 855,
#  'cumbia villera': 856,
#  'kentucky indie': 857,
#  'barnmusik': 858,
#  'deep gothic post-punk': 859,
#  'asmr': 860,
#  'alternative rock': 861,
#  'contemporary post-bop': 862,
#  'free jazz': 863,
#  'monterrey indie': 864,
#  'manchester hip hop': 865,
#  'string quartet': 866,
#  'country gospel': 867,
#  'wu fam': 868,
#  'nordic post-rock': 869,
#  'connecticut indie': 870,
#  'louvor': 871,
#  'swedish hard rock': 872,
#  'classic pakistani pop': 873,
#  'deep east coast hip hop': 874,
#  'turkish classical performance': 875,
#  'latintronica': 876,
#  'vocal harmony group': 877,
#  'ballet class': 878,
#  'spa': 879,
#  'hopebeat': 880,
#  'polish modern jazz': 881,
#  'classic eurovision': 882,
#  'punk rock italiano': 883,
#  'humppa': 884,
#  'pop rock brasileiro': 885,
#  'healing': 886,
#  'pibroch': 887,
#  'hammond organ': 888,
#  'tamil worship': 889,
#  'cambridge choir': 890,
#  'jazz organ': 891,
#  'ilahiler': 892,
#  'kent indie': 893,
#  'xtra raw': 894,
#  'focus beats': 895,
#  'azeri traditional': 896,
#  'swiss black metal': 897,
#  'nottingham indie': 898,
#  'prepared piano': 899,
#  'atmospheric dnb': 900,
#  'buffalo ny indie': 901,
#  'big band': 902,
#  'progressive metalcore': 903,
#  'chilean rock': 904,
#  'second line': 905,
#  'post-punk': 906,
#  'german rock': 907,
#  'salsa colombiana': 908,
#  'bluegrass gospel': 909,
#  'mexican traditional': 910,
#  'guzheng': 911,
#  'detroit trap': 912,
#  'dominican pop': 913,
#  'british experimental': 914,
#  'serbian electronic': 915,
#  'kirtan': 916,
#  'scandinavian r&b': 917,
#  'latin rock': 918,
#  'canadian ccm': 919,
#  'kleine hoerspiel': 920,
#  'austin singer-songwriter': 921,
#  'danish electronic': 922,
#  'chattanooga indie': 923,
#  'classic swedish pop': 924,
#  'nova canco': 925,
#  'christian metal': 926,
#  'french romanticism': 927,
#  'military cadence': 928,
#  'chicago soul': 929,
#  'hiplife': 930,
#  'brighton indie': 931,
#  'dark hardcore': 932,
#  'italian disco': 933,
#  'atl hip hop': 934,
#  'utah indie': 935,
#  'lancashire indie': 936,
#  'belgian pop': 937,
#  'tropicalia': 938,
#  'brit funk': 939,
#  'russian romanticism': 940,
#  'cabaret': 941,
#  'quebec death metal': 942,
#  'marimba orquesta': 943,
#  'kc indie': 944,
#  'reggaeton flow': 945,
#  'mexican rock': 946,
#  'kids dance party': 947,
#  'israeli singer-songwriter': 948,
#  'happy hardcore': 949,
#  'prog quebec': 950,
#  'stomp and flutter': 951,
#  'k-rap': 952,
#  'cambodian rock': 953,
#  'deep latin christian': 954,
#  'jazz colombiano': 955,
#  'british comedy': 956,
#  'nordic contemporary classical': 957,
#  'louisville underground': 958,
#  'roots reggae': 959,
#  'banda caliente': 960,
#  'swiss metal': 961,
#  'canadian psychedelic': 962,
#  'ukrainian electronic': 963,
#  'lds youth': 964,
#  'metalcore': 965,
#  'swedish synthpop': 966,
#  'musica nicaraguense': 967,
#  'soviet synthpop': 968,
#  'chamber choir': 969,
#  'vietnamese bolero': 970,
#  'vapor trap': 971,
#  'cumbia salvadorena': 972,
#  'garage rock revival': 973,
#  'bajki': 974,
#  'wyoming indie': 975,
#  'deep southern trap': 976,
#  'trad jazz catala': 977,
#  'electropop': 978,
#  'comic metal': 979,
#  'blues latinoamericano': 980,
#  'hammered dulcimer': 981,
#  'ryukyu ongaku': 982,
#  'marathi pop': 983,
#  'denpa-kei': 984,
#  'vapor soul': 985,
#  'trap queen': 986,
#  'synthwave': 987,
#  'classical': 988,
#  'gbvfi': 989,
#  'boston indie': 990,
#  'southern soul': 991,
#  'pop nacional': 992,
#  'progressive power metal': 993,
#  'french indie pop': 994,
#  'dreamgaze': 995,
#  'texas punk': 996,
#  'accordeon': 997,
#  'folkmusik': 998,
#  'russian post-punk': 999,
#  ...}

# %%
int2genre = {index: genre for genre, index in genre2int.items()}

int2genre
# Out:
# {0: 'vancouver metal',
#  1: 'hip hop cubano',
#  2: 'italian gothic',
#  3: 'arabesk',
#  4: 'psychedelic doom',
#  5: 'washboard',
#  6: 'tollywood',
#  7: 'finnish heavy metal',
#  8: 'auckland indie',
#  9: 'australian ambient',
#  10: 'finnish edm',
#  11: 'indian instrumental',
#  12: 'classical trumpet',
#  13: 'canzone napoletana',
#  14: 'kashmiri pop',
#  15: 'tabla',
#  16: 'world worship',
#  17: 'corridos tumbados',
#  18: 'american contemporary classical',
#  19: 'boston hardcore',
#  20: 'modern folk rock',
#  21: 'bansuri',
#  22: 'opera metal',
#  23: 'nova mpb',
#  24: 'opera chorus',
#  25: 'bandoneon',
#  26: 'reggaeton',
#  27: 'jazz blues',
#  28: 'chaotic hardcore',
#  29: 'caucasian classical piano',
#  30: 'hard minimal techno',
#  31: 'israeli hip hop',
#  32: 'italian jazz',
#  33: 'nyc rap',
#  34: 'hardcore techno',
#  35: 'mandolin',
#  36: 'kingston on indie',
#  37: 'classic greek pop',
#  38: 'new york drill',
#  39: 'banda',
#  40: 'corrido',
#  41: 'english indie rock',
#  42: 'pinoy hip hop',
#  43: 'dutch rock',
#  44: 'russian pop',
#  45: 'new jersey rap',
#  46: 'spanish hip hop',
#  47: 'filmi',
#  48: 'finnish metal',
#  49: 'uplifting trance',
#  50: 'meme rap',
#  51: 'jazz metal',
#  52: 'nantes indie',
#  53: 'instrumental acoustic guitar',
#  54: 'post-minimalism',
#  55: 'deep euro house',
#  56: 'christmas product',
#  57: 'ska chileno',
#  58: 'musica paraibana',
#  59: 'historic string quartet',
#  60: 'surf music',
#  61: 'broadway',
#  62: 'syrian pop',
#  63: 'devon indie',
#  64: 'grave wave',
#  65: 'd-beat',
#  66: 'classic soul',
#  67: 'instrumental bluegrass',
#  68: 'dc indie',
#  69: 'portuguese early music',
#  70: 'deathcore',
#  71: 'j-pop girl group',
#  72: 'jamgrass',
#  73: 'japanese rockabilly',
#  74: 'german power metal',
#  75: 'guinean pop',
#  76: 'reggae rock',
#  77: 'brazilian contemporary classical',
#  78: 'lo-fi',
#  79: 'austrian classical piano',
#  80: 'classical piano',
#  81: 'belarusian pop',
#  82: 'dark jazz',
#  83: 'psychedelic folk rock',
#  84: 'son cubano clasico',
#  85: 'delta blues',
#  86: 'chakra',
#  87: 'finnish hard rock',
#  88: 'rosary',
#  89: 'japanese concert band',
#  90: 'c-pop',
#  91: 'pop rap',
#  92: 'argentine telepop',
#  93: 'rare groove',
#  94: 'zurich indie',
#  95: 'ok indie',
#  96: 'livetronica',
#  97: 'neo-traditional bluegrass',
#  98: 'musikkorps',
#  99: 'oc indie',
#  100: 'danish punk',
#  101: 'hungarian classical performance',
#  102: 'folk rock',
#  103: 'hungarian folk',
#  104: 'canadian rock',
#  105: 'viral pop',
#  106: 'vienna indie',
#  107: 'japanese electronic',
#  108: 'nwothm',
#  109: 'instrumental math rock',
#  110: 'greek contemporary classical',
#  111: 'organic electronic',
#  112: '"preschool childrens music"',
#  113: 'narodna muzika',
#  114: 'czech classical',
#  115: 'j-acoustic',
#  116: 'japanese heavy metal',
#  117: 'german trance',
#  118: 'progressive psytrance',
#  119: 'madrigal',
#  120: 'uk house',
#  121: 'comic',
#  122: 'chanson',
#  123: 'tunisian pop',
#  124: 'japanese electropop',
#  125: 'musica llanera',
#  126: 'classic uk pop',
#  127: 'braindance',
#  128: 'desi hip hop',
#  129: 'sound art',
#  130: 'turkish experimental',
#  131: 'swedish heavy metal',
#  132: 'berlin minimal techno',
#  133: 'soft rock',
#  134: 'classical piano duo',
#  135: 'baltimore indie',
#  136: 'maine indie',
#  137: 'scottish electronic',
#  138: 'indie electronica',
#  139: 'velha guarda',
#  140: 'spanish invasion',
#  141: 'dutch prog',
#  142: 'mexican rock-and-roll',
#  143: 'atmospheric post-metal',
#  144: 'cameroonian pop',
#  145: 'industrial rock',
#  146: 'abstract',
#  147: 'eugene indie',
#  148: 'spanish modern rock',
#  149: 'folk metal',
#  150: 'deep melodic metalcore',
#  151: '"british childrens music"',
#  152: 'spanish rock',
#  153: 'german orchestra',
#  154: 'harmonica jazz',
#  155: 'uk alternative pop',
#  156: 'smooth saxophone',
#  157: 'rock steady',
#  158: 'british folk',
#  159: 'japanese soundtrack',
#  160: 'romanian classical piano',
#  161: 'kentucky hip hop',
#  162: 'dutch indie',
#  163: 'gothic alternative',
#  164: 'samba',
#  165: 'rap nacional antigo',
#  166: 'musica antigua',
#  167: 'italian blues',
#  168: 'post-grunge',
#  169: 'hi-nrg',
#  170: 'australian talent show',
#  171: 'sound team',
#  172: 'belgian singer-songwriter',
#  173: 'chilean hardcore',
#  174: 'post-doom metal',
#  175: 'indietronica',
#  176: 'chutney',
#  177: 'canadian blues',
#  178: 'rock drums',
#  179: 'gothic metal',
#  180: 'american 21st century classical',
#  181: 'indie poptimism',
#  182: 'pop quebecois',
#  183: 'mpb',
#  184: 'athens indie',
#  185: 'canadian indie',
#  186: 'german opera',
#  187: 'portland indie',
#  188: 'danish metal',
#  189: 'oakland indie',
#  190: 'mod revival',
#  191: 'uk hip hop',
#  192: 'dinner jazz',
#  193: 'folklore peruano',
#  194: 'italian renaissance',
#  195: 'punjabi hip hop',
#  196: 'jazz trumpet',
#  197: 'irish dance',
#  198: 'afroswing',
#  199: 'underground power pop',
#  200: 'swancore',
#  201: 'iowa hip hop',
#  202: 'oceania soundtrack',
#  203: 'sound',
#  204: 'lullaby',
#  205: 'zydeco',
#  206: 'hindi indie',
#  207: 'chillhop',
#  208: 'visor',
#  209: 'balkan brass',
#  210: 'kodomo no ongaku',
#  211: 'contemporary vocal jazz',
#  212: 'histoire pour enfants',
#  213: 'deep smooth jazz',
#  214: 'canadian comedy',
#  215: 'yacht rock',
#  216: 'stomp and holler',
#  217: 'indian classical',
#  218: 'anthem emo',
#  219: 'new england americana',
#  220: 'kizomba antigas',
#  221: 'afrofuturism',
#  222: 'piano mpb',
#  223: 'rochester ny indie',
#  224: 'rock urbano mexicano',
#  225: 'nueva ola peruana',
#  226: 'psicodelia brasileira',
#  227: 'afrobeat',
#  228: 'emo rap',
#  229: 'swedish prog',
#  230: 'reggae',
#  231: 'swedish singer-songwriter',
#  232: 'orchestra',
#  233: 'psybass',
#  234: 'frenchcore',
#  235: 'pop folk',
#  236: 'brostep',
#  237: 'yorkshire folk',
#  238: 'albuquerque indie',
#  239: 'middle east hip hop',
#  240: 'vocal ensemble',
#  241: 'rhode island rap',
#  242: 'italian classical guitar',
#  243: 'acoustic blues',
#  244: 'deep g funk',
#  245: 'colombian pop',
#  246: 'gospel',
#  247: 'mississippi indie',
#  248: 'german renaissance',
#  249: 'estonian pop',
#  250: 'quiet storm',
#  251: '"canzone dautore"',
#  252: 'latin metal',
#  253: 'canadian indigenous hip hop',
#  254: 'baroque ensemble',
#  255: 'family gospel',
#  256: 'samba-enredo',
#  257: 'pop peruano',
#  258: 'portland metal',
#  259: 'nightrun',
#  260: 'chill pop',
#  261: 'minimal wave',
#  262: 'miami metal',
#  263: 'german jazz',
#  264: 'bay area indie',
#  265: 'indian edm',
#  266: 'pop violin',
#  267: 'irish country',
#  268: 'grupera',
#  269: 'swedish alternative rock',
#  270: 'russian ccm',
#  271: 'world meditation',
#  272: 'electro swing',
#  273: 'cypriot pop',
#  274: 'japanese chillhop',
#  275: 'italian mezzo-soprano',
#  276: 'cambridgeshire indie',
#  277: 'nintendocore',
#  278: 'streichquartett',
#  279: 'kentucky mountain folk',
#  280: 'swedish garage rock',
#  281: 'one-person band',
#  282: 'theremin',
#  283: 'classic czech pop',
#  284: 'britpop',
#  285: 'bible',
#  286: 'shabad',
#  287: 'brazilian edm',
#  288: 'sufi chant',
#  289: 'japanese instrumental',
#  290: 'bard',
#  291: 'san antonio rap',
#  292: 'glam punk',
#  293: 'american modern classical',
#  294: 'indie cafe pop',
#  295: 'diva house',
#  296: 'african reggae',
#  297: 'martial industrial',
#  298: 'atlanta indie',
#  299: 'south carolina indie',
#  300: 'cumbia peruana',
#  301: 'g funk',
#  302: 'philly soul',
#  303: 'impressionism',
#  304: 'dansband',
#  305: 'binaural',
#  306: 'classical bass',
#  307: 'christian hip hop',
#  308: 'pinoy indie',
#  309: 'traditional folk',
#  310: 'chamber folk',
#  311: 'danish pop rock',
#  312: 'soul jazz',
#  313: 'russian folk rock',
#  314: 'shanty',
#  315: 'swedish americana',
#  316: 'pakistani folk',
#  317: 'turkish trap',
#  318: 'depressive black metal',
#  319: 'trap chileno',
#  320: 'tennessee hip hop',
#  321: 'omaha indie',
#  322: 'rap conscient',
#  323: 'cello',
#  324: 'pagode baiano',
#  325: 'polyphony',
#  326: 'parody',
#  327: 'spanish baroque',
#  328: 'j-pixie',
#  329: 'ethereal wave',
#  330: 'guitarra argentina',
#  331: 'uk post-hardcore',
#  332: 'sudanese pop',
#  333: 'rock baiano',
#  334: 'austindie',
#  335: 'st louis rap',
#  336: 'pub rock',
#  337: 'classic israeli pop',
#  338: 'rock nacional brasileiro',
#  339: 'north east england indie',
#  340: 'musica popular paraense',
#  341: 'japanese pop punk',
#  342: 'french opera',
#  343: 'deep soft rock',
#  344: 'japanese classical',
#  345: 'japanese r&b',
#  346: 'west end',
#  347: 'neoclassical darkwave',
#  348: 'musica andina',
#  349: 'muzica populara',
#  350: 'vocal trance',
#  351: 'chamber pop',
#  352: 'middle earth',
#  353: 'dallas indie',
#  354: 'japanese city pop',
#  355: 'early american folk',
#  356: 'deep disco',
#  357: 'uk post-punk',
#  358: 'teen pop',
#  359: 'swedish pop',
#  360: 'electro house',
#  361: 'acoustic punk',
#  362: 'classic russian pop',
#  363: 'piano rock',
#  364: 'swedish electronic',
#  365: 'scream rap',
#  366: 'australian alternative rock',
#  367: 'kawaii metal',
#  368: 'late romantic era',
#  369: 'boom bap',
#  370: 'relaxative',
#  371: 'dark techno',
#  372: 'west coast reggae',
#  373: 'disco house',
#  374: 'swedish synth',
#  375: 'french soundtrack',
#  376: 'musica para criancas',
#  377: 'mellow gold',
#  378: 'melodic rap',
#  379: 'progressive alternative',
#  380: 'tango cancion',
#  381: 'hard alternative',
#  382: 'classic j-rock',
#  383: 'indie quebecois',
#  384: 'oakland hip hop',
#  385: 'alaska indie',
#  386: 'turkish trap pop',
#  387: 'icelandic pop',
#  388: 'turkish edm',
#  389: 'native american contemporary',
#  390: 'partyschlager',
#  391: 'hungarian contemporary classical',
#  392: 'jazz tuba',
#  393: 'baglama',
#  394: 'mathcore',
#  395: 'nepali pop',
#  396: 'esperanto',
#  397: 'deep free jazz',
#  398: 'salsa international',
#  399: 'bachata',
#  400: 'classical countertenor',
#  401: 'psychill',
#  402: 'funk rock',
#  403: 'ska',
#  404: 'gaming edm',
#  405: 'swedish metal',
#  406: 'nz indie',
#  407: 'deep new americana',
#  408: 'greek pop',
#  409: 'freakbeat',
#  410: 'chamber ensemble',
#  411: 'chinese classical performance',
#  412: 'drill and bass',
#  413: 'canadian classical',
#  414: 'boogie',
#  415: 'christian a cappella',
#  416: 'florida rap',
#  417: 'bush ballad',
#  418: 'folk punk',
#  419: 'melbourne indie',
#  420: 'ambient idm',
#  421: 'latino comedy',
#  422: 'viola',
#  423: 'hong kong indie',
#  424: 'oshare kei',
#  425: 'asbury park indie',
#  426: 'ilocano pop',
#  427: 'icelandic experimental',
#  428: 'dangdut',
#  429: 'cumbia colombiana regia',
#  430: 'dark disco',
#  431: 'early music ensemble',
#  432: 'synthpop',
#  433: 'yugoslav new wave',
#  434: 'bay area hip hop',
#  435: 'honky tonk',
#  436: 'kentucky punk',
#  437: 'electro jazz',
#  438: 'york indie',
#  439: 'rabindra sangeet',
#  440: 'speed metal',
#  441: 'gypsy jazz',
#  442: 'dirty texas rap',
#  443: 'taiwan campus folk',
#  444: 'modern rock',
#  445: 'deep minimal techno',
#  446: 'german punk',
#  447: 'classical harp',
#  448: 'channel islands indie',
#  449: 'post-post-hardcore',
#  450: 'sevdah',
#  451: 'german soundtrack',
#  452: 'dutch edm',
#  453: 'la pop',
#  454: 'islamic recitation',
#  455: 'turkish jazz',
#  456: 'progressive trance',
#  457: 'gainesville indie',
#  458: 'idaho indie',
#  459: 'australian indie rock',
#  460: 'romanian electronic',
#  461: 'filthstep',
#  462: 'burmese traditional',
#  463: 'jewish hip hop',
#  464: 'indie rock',
#  465: 'deep soundtrack',
#  466: 'future funk',
#  467: 'guatemalan pop',
#  468: 'sovietwave',
#  469: 'turntablism',
#  470: 'rap dominicano',
#  471: 'nz punk',
#  472: 'vancouver indie',
#  473: 'musique peule',
#  474: 'belgian new wave',
#  475: 'ranchera',
#  476: 'rock kapak',
#  477: 'icelandic jazz',
#  478: 'electronic djent',
#  479: 'italian baroque ensemble',
#  480: 'turkish classical',
#  481: 'hindustani instrumental',
#  482: 'sheffield indie',
#  483: 'traditional country',
#  484: 'classic psychedelic rock',
#  485: 'lilith',
#  486: 'hauntology',
#  487: 'japanese post-hardcore',
#  488: 'grime',
#  489: 'sotalaulut',
#  490: 'christian rock',
#  491: 'texas country',
#  492: 'duduk',
#  493: 'classic garage rock',
#  494: 'israeli mediterranean',
#  495: 'mambo',
#  496: 'australian psych',
#  497: 'nouvelle chanson francaise',
#  498: 'merseybeat',
#  499: 'cymraeg',
#  500: 'dub poetry',
#  501: 'shakuhachi',
#  502: 'beach music',
#  503: 'hurdy-gurdy',
#  504: 'bhajan',
#  505: 'louisiana blues',
#  506: 'rune folk',
#  507: 'neofolk',
#  508: 'corrosion',
#  509: 'belarusian indie',
#  510: 'retro soul',
#  511: 'indian jazz',
#  512: 'afro house',
#  513: 'swedish jazz orkester',
#  514: 'soda pop',
#  515: 'swedish melodic rock',
#  516: 'georgian folk',
#  517: 'flick hop',
#  518: 'american orchestra',
#  519: 'belgian techno',
#  520: 'cinematic post-rock',
#  521: 'argentine ambient',
#  522: 'classic afrobeat',
#  523: 'nu age',
#  524: 'italian power metal',
#  525: 'nashville sound',
#  526: 'pop romantico',
#  527: 'tex-mex',
#  528: 'minimal melodic techno',
#  529: 'italian library music',
#  530: 'new orleans jazz',
#  531: 'classic danish pop',
#  532: 'pittsburgh rap',
#  533: '"childrens music"',
#  534: 'rock chapin',
#  535: 'australian post-punk',
#  536: 'canadian folk',
#  537: 'western swing',
#  538: 'italian indie pop',
#  539: 'experimental jazz',
#  540: 'pakistani pop',
#  541: 'nigerian hip hop',
#  542: 'exotica',
#  543: 'new americana',
#  544: 'anarcho-punk',
#  545: 'birmingham metal',
#  546: 'eastern bloc groove',
#  547: 'roots rock',
#  548: 'deep techno',
#  549: 'swedish jazz',
#  550: 'atlanta punk',
#  551: 'puerto rican folk',
#  552: 'belgian edm',
#  553: 'taiwan indie',
#  554: 'triangle indie',
#  555: 'plunderphonics',
#  556: 'korean classical performance',
#  557: 'marching band',
#  558: 'afro dancehall',
#  559: 'cumbia ranchera',
#  560: 'breakcore',
#  561: 'celtic punk',
#  562: 'dixieland',
#  563: 'rap',
#  564: 'jazz double bass',
#  565: 'minneapolis indie',
#  566: 'okinawan pop',
#  567: 'background music',
#  568: 'sky room',
#  569: 'panamanian rock',
#  570: 'rock alternativo brasileiro',
#  571: 'swedish choir',
#  572: 'dungeon synth',
#  573: 'polish post-rock',
#  574: 'dance-punk',
#  575: 'hands up',
#  576: 'indonesian r&b',
#  577: 'spanish pop',
#  578: 'appalachian folk',
#  579: 'australian metal',
#  580: 'country dawn',
#  581: 'vermont indie',
#  582: 'vancouver punk',
#  583: 'contemporary classical',
#  584: 'australian electropop',
#  585: 'polish classical piano',
#  586: 'kiwi rock',
#  587: 'gospel antigas',
#  588: 'tamaulipas indie',
#  589: 'christian music',
#  590: 'rhode island indie',
#  591: 'spanish techno',
#  592: 'light music',
#  593: 'hawaiian indie',
#  594: 'caucasian classical',
#  595: 'drift',
#  596: 'san diego indie',
#  597: 'lute',
#  598: 'jazz funk',
#  599: 'memphis indie',
#  600: 'halloween',
#  601: 'latin classical',
#  602: 'baroque violin',
#  603: 'lo-fi house',
#  604: 'sad rap',
#  605: 'deep ragga',
#  606: 'old school rap francais',
#  607: 'polka',
#  608: 'meditation',
#  609: 'ethio-jazz',
#  610: 'dubsteppe',
#  611: 'musica de fondo',
#  612: 'calming instrumental',
#  613: 'french dnb',
#  614: 'indie deutschrap',
#  615: 'musica gaucha tradicionalista',
#  616: 'shaabi',
#  617: 'pony',
#  618: 'columbus ohio indie',
#  619: 'j-punk',
#  620: 'danish pop',
#  621: 'beatlesque',
#  622: 'bassline',
#  623: 'arab pop',
#  624: 'brega',
#  625: 'melancholia',
#  626: 'turkish pop',
#  627: 'austrian orchestra',
#  628: 'jazz cubano',
#  629: 'salsa',
#  630: 'j-metal',
#  631: 'bossa nova jazz',
#  632: 'new age',
#  633: 'spanish metal',
#  634: 'boston folk',
#  635: 'minimal tech house',
#  636: 'gothic rock',
#  637: 'instrumental grime',
#  638: 'latin talent show',
#  639: 'deep freestyle',
#  640: 'indonesian pop',
#  641: 'toronto rap',
#  642: 'italian contemporary jazz',
#  643: 'ambient black metal',
#  644: 'vintage schlager',
#  645: 'fo jing',
#  646: 'garage rock',
#  647: 'dembow',
#  648: 'french post-punk',
#  649: 'celtic rock',
#  650: 'nashville indie',
#  651: 'modern alternative rock',
#  652: 'british grindcore',
#  653: 'nueva ola chilena',
#  654: 'musica piemonteisa',
#  655: 'boston metal',
#  656: 'chinese soundtrack',
#  657: 'north carolina emo',
#  658: 'uk doom metal',
#  659: 'supergroup',
#  660: 'australian country',
#  661: 'swedish stoner rock',
#  662: 'gymcore',
#  663: 'psychedelic trance',
#  664: 'south carolina metal',
#  665: 'classical baritone',
#  666: 'modern old-time',
#  667: 'modern alternative pop',
#  668: 'ritmo kombina',
#  669: 'chinese jazz',
#  670: 'vgm instrumental',
#  671: 'folk-pop',
#  672: 'oud',
#  673: 'polca paraguaya',
#  674: 'kannada bhava geethe',
#  675: 'perth indie',
#  676: 'disney',
#  677: 'new weird america',
#  678: 'polynesian pop',
#  679: 'political hip hop',
#  680: 'carnatic vocal',
#  681: 'psychedelic soul',
#  682: 'show tunes',
#  683: 'christian punk',
#  684: 'neo-classical',
#  685: 'argentine indie',
#  686: 'estonian hip hop',
#  687: 'croatian folk',
#  688: 'rap kreyol',
#  689: 'chillwave',
#  690: 'circus',
#  691: 'contemporary jazz',
#  692: 'merengue tipico',
#  693: 'straight-ahead jazz',
#  694: 'ny roots',
#  695: '"muzika lyeladim"',
#  696: 'hungarian pop',
#  697: 'industrial hardcore',
#  698: 'miami bass',
#  699: 'progressive jazz fusion',
#  700: 'ottawa rap',
#  701: 'pop venezolano',
#  702: 'italian opera',
#  703: 'pop punk',
#  704: 'pixie',
#  705: 'traditional blues',
#  706: 'carnatic',
#  707: 'transpop',
#  708: 'neue deutsche todeskunst',
#  709: 'nueva cancion',
#  710: 'british modern classical',
#  711: 'cumbia sonidera',
#  712: 'samba de roda',
#  713: 'modern ska punk',
#  714: 'hawaiian',
#  715: 'classic indo pop',
#  716: 'dutch dnb',
#  717: 'string band',
#  718: 'german romanticism',
#  719: 'american folk revival',
#  720: 'seattle indie',
#  721: 'nederlandse hardstyle',
#  722: 'philly rap',
#  723: 'worship',
#  724: 'garage pop',
#  725: 'instrumental rock',
#  726: 'greek folk',
#  727: 'gothabilly',
#  728: 'jazztronica',
#  729: 'canadian experimental',
#  730: 'musica cristiana guatemalteca',
#  731: 'anglican liturgy',
#  732: 'boston rock',
#  733: 'italian progressive metal',
#  734: 'southern soul blues',
#  735: 'talent show',
#  736: 'scratch',
#  737: 'tribal house',
#  738: 'country rock',
#  739: 'jump up',
#  740: 'australian trap',
#  741: 'new england emo',
#  742: 'early avant garde',
#  743: 'birmingham hip hop',
#  744: 'latin afrobeat',
#  745: 'street punk',
#  746: 'emo punk',
#  747: 'polish contemporary classical',
#  748: 'scottish new wave',
#  749: 'canadian electropop',
#  750: 'viking black metal',
#  751: 'turkish modern jazz',
#  752: 'dub techno',
#  753: 'ambient techno',
#  754: 'birmingham grime',
#  755: 'uptempo hardcore',
#  756: 'reggae en espanol',
#  757: 'avant-garde',
#  758: 'norwegian death metal',
#  759: 'indie shoegaze',
#  760: 'vintage chinese pop',
#  761: 'brass quintet',
#  762: 'celtic metal',
#  763: 'atmospheric sludge',
#  764: 'thall',
#  765: 'groove room',
#  766: 'deep indie singer-songwriter',
#  767: 'funk paulista',
#  768: 'bristol indie',
#  769: 'danish jazz',
#  770: 'dream pop',
#  771: 'substep',
#  772: 'dabke',
#  773: 'swedish doom metal',
#  774: 'bhangra',
#  775: 'washington indie',
#  776: 'old-time fiddle',
#  777: 'jangle pop',
#  778: 'historically informed performance',
#  779: 'french movie tunes',
#  780: 'hard rock',
#  781: 'opera',
#  782: 'japanese psychedelic',
#  783: 'swedish tropical house',
#  784: 'thai pop',
#  785: 'old school thrash',
#  786: 'bubblegrunge',
#  787: 'philly indie',
#  788: 'german baroque',
#  789: 'us power metal',
#  790: 'uk diy punk',
#  791: 'rhythm and blues',
#  792: 'baroque woodwind',
#  793: 'british invasion',
#  794: 'chill guitar',
#  795: 'dutch death metal',
#  796: 'east coast hip hop',
#  797: 'nu disco',
#  798: 'ethnotronica',
#  799: 'indie rockism',
#  800: 'german underground rap',
#  801: 'german hard rock',
#  802: 'dutch trance',
#  803: 'shred',
#  804: 'classical mandolin',
#  805: 'latin ska',
#  806: 'canadian post-hardcore',
#  807: 'timba',
#  808: 'avant-garde metal',
#  809: 'gospel singers',
#  810: 'tagalog rap',
#  811: 'rennes indie',
#  812: 'milwaukee indie',
#  813: 'knoxville indie',
#  814: 'k-indie',
#  815: 'spirituals',
#  816: 'neo-rockabilly',
#  817: 'jamtronica',
#  818: 'arizona punk',
#  819: 'movie tunes',
#  820: 'classic canadian rock',
#  821: 'norwegian singer-songwriter',
#  822: 'canadian hardcore',
#  823: 'pop r&b',
#  824: 'riot grrrl',
#  825: 'japanese vocal jazz',
#  826: 'minneapolis sound',
#  827: 'erhu',
#  828: 'modular synth',
#  829: '"death n roll"',
#  830: 'experimental guitar',
#  831: 'fluxwork',
#  832: 'michigan indie',
#  833: 'baroque singing',
#  834: 'northern irish indie',
#  835: 'future rock',
#  836: 'j-pop',
#  837: 'german classical piano',
#  838: 'american primitive',
#  839: 'australian choir',
#  840: 'deep flow',
#  841: 'witch house',
#  842: 'gothic black metal',
#  843: 'tagalog worship',
#  844: 'lldm',
#  845: 'metropopolis',
#  846: 'romanian pop',
#  847: 'swedish power metal',
#  848: 'greek swing',
#  849: 'folk rock italiano',
#  850: 'jazz guitar',
#  851: 'art punk',
#  852: 'japanese folk',
#  853: 'tulsa indie',
#  854: 'panpipe',
#  855: 'venezuelan indie',
#  856: 'cumbia villera',
#  857: 'kentucky indie',
#  858: 'barnmusik',
#  859: 'deep gothic post-punk',
#  860: 'asmr',
#  861: 'alternative rock',
#  862: 'contemporary post-bop',
#  863: 'free jazz',
#  864: 'monterrey indie',
#  865: 'manchester hip hop',
#  866: 'string quartet',
#  867: 'country gospel',
#  868: 'wu fam',
#  869: 'nordic post-rock',
#  870: 'connecticut indie',
#  871: 'louvor',
#  872: 'swedish hard rock',
#  873: 'classic pakistani pop',
#  874: 'deep east coast hip hop',
#  875: 'turkish classical performance',
#  876: 'latintronica',
#  877: 'vocal harmony group',
#  878: 'ballet class',
#  879: 'spa',
#  880: 'hopebeat',
#  881: 'polish modern jazz',
#  882: 'classic eurovision',
#  883: 'punk rock italiano',
#  884: 'humppa',
#  885: 'pop rock brasileiro',
#  886: 'healing',
#  887: 'pibroch',
#  888: 'hammond organ',
#  889: 'tamil worship',
#  890: 'cambridge choir',
#  891: 'jazz organ',
#  892: 'ilahiler',
#  893: 'kent indie',
#  894: 'xtra raw',
#  895: 'focus beats',
#  896: 'azeri traditional',
#  897: 'swiss black metal',
#  898: 'nottingham indie',
#  899: 'prepared piano',
#  900: 'atmospheric dnb',
#  901: 'buffalo ny indie',
#  902: 'big band',
#  903: 'progressive metalcore',
#  904: 'chilean rock',
#  905: 'second line',
#  906: 'post-punk',
#  907: 'german rock',
#  908: 'salsa colombiana',
#  909: 'bluegrass gospel',
#  910: 'mexican traditional',
#  911: 'guzheng',
#  912: 'detroit trap',
#  913: 'dominican pop',
#  914: 'british experimental',
#  915: 'serbian electronic',
#  916: 'kirtan',
#  917: 'scandinavian r&b',
#  918: 'latin rock',
#  919: 'canadian ccm',
#  920: 'kleine hoerspiel',
#  921: 'austin singer-songwriter',
#  922: 'danish electronic',
#  923: 'chattanooga indie',
#  924: 'classic swedish pop',
#  925: 'nova canco',
#  926: 'christian metal',
#  927: 'french romanticism',
#  928: 'military cadence',
#  929: 'chicago soul',
#  930: 'hiplife',
#  931: 'brighton indie',
#  932: 'dark hardcore',
#  933: 'italian disco',
#  934: 'atl hip hop',
#  935: 'utah indie',
#  936: 'lancashire indie',
#  937: 'belgian pop',
#  938: 'tropicalia',
#  939: 'brit funk',
#  940: 'russian romanticism',
#  941: 'cabaret',
#  942: 'quebec death metal',
#  943: 'marimba orquesta',
#  944: 'kc indie',
#  945: 'reggaeton flow',
#  946: 'mexican rock',
#  947: 'kids dance party',
#  948: 'israeli singer-songwriter',
#  949: 'happy hardcore',
#  950: 'prog quebec',
#  951: 'stomp and flutter',
#  952: 'k-rap',
#  953: 'cambodian rock',
#  954: 'deep latin christian',
#  955: 'jazz colombiano',
#  956: 'british comedy',
#  957: 'nordic contemporary classical',
#  958: 'louisville underground',
#  959: 'roots reggae',
#  960: 'banda caliente',
#  961: 'swiss metal',
#  962: 'canadian psychedelic',
#  963: 'ukrainian electronic',
#  964: 'lds youth',
#  965: 'metalcore',
#  966: 'swedish synthpop',
#  967: 'musica nicaraguense',
#  968: 'soviet synthpop',
#  969: 'chamber choir',
#  970: 'vietnamese bolero',
#  971: 'vapor trap',
#  972: 'cumbia salvadorena',
#  973: 'garage rock revival',
#  974: 'bajki',
#  975: 'wyoming indie',
#  976: 'deep southern trap',
#  977: 'trad jazz catala',
#  978: 'electropop',
#  979: 'comic metal',
#  980: 'blues latinoamericano',
#  981: 'hammered dulcimer',
#  982: 'ryukyu ongaku',
#  983: 'marathi pop',
#  984: 'denpa-kei',
#  985: 'vapor soul',
#  986: 'trap queen',
#  987: 'synthwave',
#  988: 'classical',
#  989: 'gbvfi',
#  990: 'boston indie',
#  991: 'southern soul',
#  992: 'pop nacional',
#  993: 'progressive power metal',
#  994: 'french indie pop',
#  995: 'dreamgaze',
#  996: 'texas punk',
#  997: 'accordeon',
#  998: 'folkmusik',
#  999: 'russian post-punk',
#  ...}

# %% [markdown]
# practice "vectorizing" one song input

# %%
corpus[8]
# Out:
# 'comedy rock, comic, parody'

# %%
corpus = corpus.str.split(', ')

# %%
corpus.head()
# Out:
# 0                                          [show tunes]
# 8                          [comedy rock, comic, parody]
# 9     [emo rap, florida rap, sad rap, underground hi...
# 10                                [dark trap, meme rap]
# 12    [asian american hip hop, cali rap, west coast ...
# Name: genres, dtype: object

# %%
example = [genre2int[genre] for genre in corpus[8]]
example
# Out:
# [2331, 121, 326]

# %% [markdown]
# ## Generating skip-grams

# %%
import io
import itertools
import numpy as np
import os
import re
import string
import tensorflow as tf
import tqdm

from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, Dot, Embedding, Flatten, GlobalAveragePooling1D, Reshape
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %%
# pip install -q tqdm

# %%
SEED = 42

# %%
songgenres = list(corpus)

# %%
songgenres[:5]
# Out:
# [['show tunes'],
#  ['comedy rock', 'comic', 'parody'],
#  ['emo rap', 'florida rap', 'sad rap', 'underground hip hop', 'vapor trap'],
#  ['dark trap', 'meme rap'],
#  ['asian american hip hop', 'cali rap', 'west coast trap']]

# %%
# songgenres = []
# for song in corpus:
#     songgenres.append(song.split(", "))
    
# songgenres

# %%
songgenresint = []
for song in songgenres:
    songgenresint.append([genre2int[genre] for genre in song])
    
songgenresint[:5]
# Out:
# [[682],
#  [2331, 121, 326],
#  [228, 416, 604, 2230, 971],
#  [2342, 50],
#  [2180, 2810, 2713]]

# %% [markdown]
# I attempted the build in preprocessing function but I am unclear how to process the entire songgenresint corpus. It seems to spit out something that makes no sense. If I do it on one sequence of genres, it seems to work better but it doesn't use tuples which is super confusing? the documentation says it should return tuples.

# %%
WINDOW_SIZE = 6

positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
      songgenresint[1], 
      vocabulary_size=len(genres),
      window_size=WINDOW_SIZE,
      negative_samples=0)
print(len(positive_skip_grams))
# Out:
# 6

# %%
positive_skip_grams
# Out:
# [[2331, 121], [326, 2331], [326, 121], [121, 326], [2331, 326], [121, 2331]]

# %% [markdown]
# Generating positive skip gram pairs manually. This should be a list of tuples of the SG pairs in index format (integer).

# %%
WINDOW_SIZE = 6

pos_sg_pairs = []
for song in songgenres:
    for idx, genre in enumerate(song):
        for neighbor in song[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(song)) + 1] : 
            if neighbor != genre:
                pos_sg_pairs.append((genre2int[genre], genre2int[neighbor]))
                
pos_sg_pairs[:5]
# Out:
# [(2331, 121), (2331, 326), (121, 2331), (121, 326), (326, 2331)]

# %%
len(pos_sg_pairs)
# Out:
# 266084

# %%
test = set(pos_sg_pairs)
len(test)

#I think you want the duplicates but I'm not entirely sure...
# Out:
# 51140

# %% [markdown]
# Generating the negative samples for training using random words that wouldn't be found in positive skip gram pairs.
#
# Here's me playing around with one set of negative samples for one target word found at pos_sg_pairs[0].

# %%
# Get target and context words for one positive skip-gram.
target_word, context_word = pos_sg_pairs[0]

# Set the number of negative samples per positive context.
# Using 3 since my dataset is rather large
num_ns = 3

context_class = tf.reshape(tf.constant(context_word, dtype="int64"), (1, 1))
neg_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
    true_classes=context_class, # class that should be sampled as 'positive'
    num_true=1, # each positive skip-gram has 1 positive context class
    num_sampled=num_ns, # number of negative context words to sample
    unique=True, # all the negative samples should be unique
    range_max=len(genres), # pick index of the samples from [0, vocab_size]
    seed=SEED, # seed for reproducibility
    name="negative_sampling" # name of this operation
)
print(neg_sampling_candidates)
print([int2genre[index.numpy()] for index in neg_sampling_candidates])
# Out:
# tf.Tensor([139  17 637], shape=(3,), dtype=int64)
# ['velha guarda', 'corridos tumbados', 'instrumental grime']

# %% [markdown]
# Seems like what we do next is batch the positive skipgram with its corresponding negative sampling candidates into one tensor object. this produces a set of positive skipgrams (labelled as `1`) and set of negative samples (labelled as `0`) for each target word.

# %%
# Add a dimension so you can use concatenation (on the next step).
neg_sampling_candidates = tf.expand_dims(neg_sampling_candidates, 1)

# Concat positive context word with negative sampled words.
context = tf.concat([context_class, neg_sampling_candidates], 0)

# Label first context word as 1 (positive) followed by num_ns 0s (negative).
label = tf.constant([1] + [0]*num_ns, dtype="int64") 

# Reshape target to shape (1,) and context and label to (num_ns+1,).
target = tf.squeeze(target_word)
context = tf.squeeze(context)
label =  tf.squeeze(label)

# %%
print(f"target_index    : {target}")
print(f"target_word     : {int2genre[target_word]}")
print(f"context_indices : {context}")
print(f"context_words   : {[int2genre[c.numpy()] for c in context]}")
print(f"label           : {label}")
# Out:
# target_index    : 2331
# target_word     : comedy rock
# context_indices : [121 139  17 637]
# context_words   : ['comic', 'velha guarda', 'corridos tumbados', 'instrumental grime']
# label           : [1 0 0 0]

# %% [markdown]
# So we have 3 bits of information tied to each target word: 1) the `target_index` found in the `genres` list, 2) the `context` which tells you what the context word is as seen in the positive skipgram pair, in addition to the negative samples and 3) the `labels` object which boolean expressive which word in the `context` object is the positive context word (represented as `1`) and which are negative samples (representeed with `0`).
#
# A tuple of `(target, context, label)` tensors constitutes *one training example* for training your skip-gram negative sampling Word2Vec model. Notice that the target is of shape (1,) while the context and label are of shape (1+num_ns,)

# %%
print(f"target  :", target)
print(f"context :", context )
print(f"label   :", label )
# Out:
# target  : tf.Tensor(2331, shape=(), dtype=int32)
# context : tf.Tensor([121 139  17 637], shape=(4,), dtype=int64)
# label   : tf.Tensor([1 0 0 0], shape=(4,), dtype=int64)

# %% [markdown]
# ## Scaling Up: Generating Full Train Data
#
# Now we'll take all steps above and write a function to handle a list of vectorized "sentences" (or vectorize genre list in this case). A *sampling table* is built first and the tuples of target, context and labels are generated.

# %%
# Generates skip-gram pairs with negative sampling for a list of sequences
# (int-encoded sentences) based on window size, number of negative samples
# and genre-options size.
def generate_training_data(sequences, window_size, num_ns, vocab_size, seed):
  # Elements of each training example are appended to these lists.
  targets, contexts, labels = [], [], []

  # Build the sampling table for vocab_size tokens.
  sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(vocab_size)

  # Iterate over all sequences (sentences) in dataset.
  for sequence in tqdm.tqdm(sequences):

    # Generate positive skip-gram pairs for a sequence (sentence).
    positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
          sequence, 
          vocabulary_size=vocab_size,
          sampling_table=sampling_table,
          window_size=window_size,
          negative_samples=0)

    # Iterate over each positive skip-gram pair to produce training examples 
    # with positive context word and negative samples.
    for target_word, context_word in positive_skip_grams:
      context_class = tf.expand_dims(
          tf.constant([context_word], dtype="int64"), 1)
      negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
          true_classes=context_class,
          num_true=1, 
          num_sampled=num_ns, 
          unique=True, 
          range_max=vocab_size, 
          seed=SEED, 
          name="negative_sampling")

      # Build context and label vectors (for one target word)
      negative_sampling_candidates = tf.expand_dims(
          negative_sampling_candidates, 1)

      context = tf.concat([context_class, negative_sampling_candidates], 0)
      label = tf.constant([1] + [0]*num_ns, dtype="int64")
        
      # NO SQUEEZING?
      # Reshape target to shape (1,) and context and label to (num_ns+1,).
      # target = tf.squeeze(target_word)
      # context = tf.squeeze(context)
      # label =  tf.squeeze(label)

      # Append each element from the training example to global lists.
      targets.append(target_word)
      contexts.append(context)
      labels.append(label)

  return targets, contexts, labels

# %% [markdown]
# Now I should be able to use this function to construct a list of targets, contexts, and labels.

# %%
targets, contexts, labels = generate_training_data(
    sequences=songgenresint, 
    window_size=6, 
    num_ns=3, 
    vocab_size=len(genres), 
    seed=SEED)
print(len(targets), len(contexts), len(labels))
# Out:
# 100%|██████████| 18823/18823 [00:05<00:00, 3679.01it/s]
# 85171 85171 85171

# %%
print(f"target  :", targets[0])
print(f"context :", contexts[0] )
print(f"label   :", labels[0] )
# Out:
# target  : 971
# context : tf.Tensor(
# [[2230]
#  [   4]
#  [  34]
#  [  14]], shape=(4, 1), dtype=int64)
# label   : tf.Tensor([1 0 0 0], shape=(4,), dtype=int64)

# %%
genreneighbors = pd.DataFrame(neighbors, columns = ['input', 'label'])

# %%
genreneighbors
# Out:
#                      input               label
# 0              comedy rock               comic
# 1              comedy rock              parody
# 2                    comic         comedy rock
# 3                    comic              parody
# 4                   parody         comedy rock
# ...                    ...                 ...
# 278857            mandopop               c-pop
# 278858            mandopop    classic cantopop
# 278859            mandopop    classic mandopop
# 278860       chinese indie  chinese indie rock
# 278861  chinese indie rock       chinese indie
#
# [278862 rows x 2 columns]

# %%
SEED = 42

# %%
ONE_HOT_DIM = len(genres)

# function to convert numbers to one hot vectors
def to_one_hot_encoding(data_point_index):
    one_hot_encoding = np.zeros(ONE_HOT_DIM)
    one_hot_encoding[data_point_index] = 1
    return one_hot_encoding

# %%
X = [] # input word
Y = [] # target word

for x, y in zip(genreneighbors['input'], genreneighbors['label']):
    X.append(to_one_hot_encoding(genre2int[ x ]))
    Y.append(to_one_hot_encoding(genre2int[ y ]))
    
# convert them to numpy arrays
X_train = np.asarray(X)
Y_train = np.asarray(Y)

# %%
# making placeholders for X_train and Y_train
x = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))
y_label = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))

# word embedding will be 2 dimension for 2d visualization
EMBEDDING_DIM = 10

# hidden layer: which represents word vector eventually
W1 = tf.Variable(tf.random_normal([ONE_HOT_DIM, EMBEDDING_DIM]))
b1 = tf.Variable(tf.random_normal([1])) #bias
hidden_layer = tf.add(tf.matmul(x,W1), b1)

# output layer
W2 = tf.Variable(tf.random_normal([EMBEDDING_DIM, ONE_HOT_DIM]))
b2 = tf.Variable(tf.random_normal([1]))
prediction = tf.nn.softmax(tf.add( tf.matmul(hidden_layer, W2), b2))

# loss function: cross entropy
loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.log(prediction), axis=[1]))

# training operation
train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

# %% [markdown]
# TRAIN

# %%
gpu_options = tf.GPUOptions(allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
init = tf.global_variables_initializer()
sess.run(init)

# %%
iteration = 20000
for i in range(iteration):
    # input is X_train which is one hot encoded word
    # label is Y_train which is one hot encoded neighbor word
    sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
    if i % 3000 == 0:
        print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1366     try:
# -> 1367       return fn(*args)
#    1368     except errors.OpError as e:
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1351       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1352                                       target_list, run_metadata)
#    1353
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1444                                             fetch_list, target_list,
# -> 1445                                             run_metadata)
#    1446
#
# ResourceExhaustedError: OOM when allocating tensor with shape[278862,2972] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 	 [[{{node gradients/Log_grad/Reciprocal}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-20-6c5248c105dd> in <module>
#       3     # input is X_train which is one hot encoded word
#       4     # label is Y_train which is one hot encoded neighbor word
# ----> 5     sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
#       6     if i % 3000 == 0:
#       7         print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     958     try:
#     959       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 960                          run_metadata_ptr)
#     961       if run_metadata:
#     962         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1181     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1182       results = self._do_run(handle, final_targets, final_fetches,
# -> 1183                              feed_dict_tensor, options, run_metadata)
#    1184     else:
#    1185       results = []
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1359     if handle is None:
#    1360       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1361                            run_metadata)
#    1362     else:
#    1363       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1384                     '\nsession_config.graph_options.rewrite_options.'
#    1385                     'disable_meta_optimizer = True')
# -> 1386       raise type(e)(node_def, op, message)
#    1387
#    1388   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[278862,2972] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 	 [[node gradients/Log_grad/Reciprocal (defined at <ipython-input-16-f2ed3a442883>:22) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Errors may have originated from an input operation.
# Input Source operations connected to node gradients/Log_grad/Reciprocal:
#  Softmax (defined at <ipython-input-16-f2ed3a442883>:16)
#
# Original stack trace for 'gradients/Log_grad/Reciprocal':
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 250, in wrapper
#     runner = Runner(ctx_run, result, future, yielded)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 741, in __init__
#     self.ctx_run(self.run)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 362, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 265, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-f2ed3a442883>", line 22, in <module>
#     train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/training/optimizer.py", line 403, in minimize
#     grad_loss=grad_loss)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/training/optimizer.py", line 512, in compute_gradients
#     colocate_gradients_with_ops=colocate_gradients_with_ops)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gradients_impl.py", line 158, in gradients
#     unconnected_gradients)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gradients_util.py", line 669, in _GradientsHelper
#     lambda: grad_fn(op, *out_grads))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gradients_util.py", line 336, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gradients_util.py", line 669, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py", line 668, in _LogGrad
#     return grad * math_ops.reciprocal(x)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_math_ops.py", line 7374, in reciprocal
#     "Reciprocal", x=x, name=name)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/op_def_library.py", line 742, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3322, in _create_op_internal
#     op_def=op_def)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1756, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ...which was originally created as op 'Log', defined at:
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# [elided 29 identical lines from previous traceback]
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-f2ed3a442883>", line 19, in <module>
#     loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.log(prediction), axis=[1]))
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_math_ops.py", line 5248, in log
#     "Log", x=x, name=name)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/op_def_library.py", line 742, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3322, in _create_op_internal
#     op_def=op_def)
#   File "/home/dgsparks/anaconda3/envs/neurnet/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1756, in __init__
#     self._traceback = tf_stack.extract_stack()
